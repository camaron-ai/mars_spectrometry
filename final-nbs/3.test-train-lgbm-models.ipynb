# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os

# %%
PROJECT_DIR = os.path.abspath('.')
if PROJECT_DIR.endswith('final-nbs'):
    PROJECT_DIR = os.path.abspath('../')
    os.chdir(PROJECT_DIR)

# %%
import cfg
from src.data import get_features_path_from_metadata, join_dataframe_columns
from src import util
from src.data import setup_directories
util.setup_logging()

dirs = setup_directories(cfg.DATA_DIR, create_dirs=True)

# %%
raw_dir = Path(dirs['raw'])
train_dir = Path(dirs['train'])
cv_dir = Path(dirs['cv']['test'])

# %%
# read metadata
pd_metadata = pd.read_csv(raw_dir / "metadata.csv", index_col="sample_id")
pd_metadata.head()
# Out:
#            split instrument_type             features_path  \
# sample_id
# S0000      train      commercial  train_features/S0000.csv
# S0001      train      commercial  train_features/S0001.csv
# S0002      train      commercial  train_features/S0002.csv
# S0003      train      commercial  train_features/S0003.csv
# S0004      train      commercial  train_features/S0004.csv
#
#                           features_md5_hash
# sample_id
# S0000      017b9a71a702e81a828e6242aa15f049
# S0001      0d09840214054d254bd49436c6a6f315
# S0002      3f58b3c9b001bfed6ed4e4f757083e09
# S0003      e9a12f96114a2fda60b36f4c0f513fb1
# S0004      b67603d3931897bfa796ac42cc16de78

# %%
# read train labels
pd_train_target = pd.read_csv(raw_dir / 'train_labels.csv', index_col='sample_id')
# read train labels
pd_valid_target = pd.read_csv(raw_dir / 'val_labels.csv', index_col='sample_id')

# %%
# read train labels
pd_multclass_target = pd.read_csv(train_dir / 'multiclass.csv', index_col='sample_id')
pd_agg_features = pd.read_csv(train_dir / 'mz_agg_features_drop_correlated.csv', index_col='sample_id')
pd_cluster_features = pd.read_csv(train_dir / 'ae_clusters.csv', index_col='sample_id')
pd_sample_features = pd.read_csv(train_dir / 'sample_features.csv', index_col='sample_id')
pd_features = pd.concat((pd_sample_features, pd_agg_features, pd_cluster_features), axis=1)

# %%
valid_dir = Path(dirs['valid'])

# read train labels
pd_valid_multclass_target = pd.read_csv(valid_dir / 'multiclass.csv', index_col='sample_id')
pd_valid_agg_features = pd.read_csv(valid_dir / 'mz_agg_features_drop_correlated.csv', index_col='sample_id')
pd_valid_cluster_features = pd.read_csv(valid_dir / 'ae_clusters.csv', index_col='sample_id')
pd_valid_sample_features = pd.read_csv(valid_dir / 'sample_features.csv', index_col='sample_id')
pd_valid_features = pd.concat((pd_valid_sample_features, pd_valid_agg_features, pd_valid_cluster_features), axis=1)

# %%
pd_features = pd_features.append(pd_valid_features)

# %%
pd_train_target = pd_train_target.append(pd_valid_target)

# %%
pd_multclass_target = pd_multclass_target.append(pd_valid_multclass_target)

# %%
feature_names = pd_features.columns.to_list()

# %%
from src import util

# %%
data = pd.concat((pd_train_target, pd_multclass_target, pd_features), axis=1)

# %%
data.head()
# Out:
#            basalt  carbonate  chloride  iron_oxide  oxalate  oxychlorine  \
# sample_id
# S0000           0          0         0           0        0            0
# S0001           0          1         0           0        0            0
# S0002           0          0         0           0        0            1
# S0003           0          1         0           1        0            0
# S0004           0          0         0           1        0            1
#
#            phyllosilicate  silicate  sulfate  sulfide  ...  cluster_mz90  \
# sample_id                                              ...
# S0000                   0         0        1        0  ...           9.0
# S0001                   0         0        0        0  ...          -1.0
# S0002                   0         0        0        0  ...           6.0
# S0003                   0         0        1        0  ...           6.0
# S0004                   1         0        0        0  ...           7.0
#
#            cluster_mz91  cluster_mz92  cluster_mz93  cluster_mz94  \
# sample_id
# S0000               7.0           4.0           9.0           9.0
# S0001              -1.0          -1.0          -1.0          -1.0
# S0002               7.0           6.0           7.0           6.0
# S0003               6.0           8.0           6.0           0.0
# S0004               7.0           7.0           6.0           7.0
#
#            cluster_mz95  cluster_mz96  cluster_mz97  cluster_mz98  \
# sample_id
# S0000               9.0           9.0           7.0           7.0
# S0001              -1.0          -1.0          -1.0          -1.0
# S0002               6.0           7.0           8.0           8.0
# S0003               7.0           8.0           7.0           7.0
# S0004               7.0           6.0           8.0           6.0
#
#            cluster_mz99
# sample_id
# S0000               9.0
# S0001              -1.0
# S0002               1.0
# S0003               8.0
# S0004               8.0
#
# [5 rows x 475 columns]

# %%
from src.model_selection import get_train_test_tuple_from_split
from src.data import get_cv_paths
from sklearn.linear_model import LogisticRegression
from xgboost import XGBRFClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC

# %%
model_config = {'model': 'lgbm',
                'parameters':
               {'class_weight': 'balanced',
                'n_estimators': 50, 'colsample_bytree': 0.3}}

# %%
from src import train, inference

# %%
def train_one_vs_the_rest(data: pd.DataFrame, model_config, feature_names):
    
    models = {}
    
    for target_name in cfg.TARGETS:
        cv_paths = get_cv_paths(cv_dir, target_name)
        multiclass_target_name = f'{target_name}_multiclass'
        models[target_name] = train.train_cv_from_config(data, model_config, feature_names, multiclass_target_name, cv_paths=cv_paths)
    return models

# %%
models = train_one_vs_the_rest(data, model_config, feature_names)
# Out:
# 2022-04-17 11:12:24 - src.train - INFO     [train.py:62] fold=1/33
# 2022-04-17 11:12:24 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_0.csv
# 2022-04-17 11:12:24 - src.train - INFO     [train.py:28] elapsed training time: 0.012 min
# 2022-04-17 11:12:24 - src.train - INFO     [train.py:62] fold=2/33
# 2022-04-17 11:12:24 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_1.csv
# 2022-04-17 11:12:25 - src.train - INFO     [train.py:28] elapsed training time: 0.011 min
# 2022-04-17 11:12:25 - src.train - INFO     [train.py:62] fold=3/33
# 2022-04-17 11:12:25 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_10.csv
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:28] elapsed training time: 0.009 min
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:62] fold=4/33
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_11.csv
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:28] elapsed training time: 0.009 min
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:62] fold=5/33
# 2022-04-17 11:12:26 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_12.csv
# 2022-04-17 11:12:27 - src.train - INFO     [train.py:28] elapsed training time: 0.008 min
# 2022-04-17 11:12:27 - src.train - INFO     [train.py:62] fold=6/33
# 2022-04-17 11:12:27 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_13.csv
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:28] elapsed training time: 0.009 min
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:62] fold=7/33
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_14.csv
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:28] elapsed training time: 0.009 min
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:62] fold=8/33
# 2022-04-17 11:12:28 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_15.csv
# 2022-04-17 11:12:29 - src.train - INFO     [train.py:28] elapsed training time: 0.016 min
# 2022-04-17 11:12:29 - src.train - INFO     [train.py:62] fold=9/33
# 2022-04-17 11:12:29 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold_16.csv
# 2022-04-17 11:12:30 - src.train - INFO     [train.py:28] elapsed training time: 0.010 min
# 2022-04-17 11:12:30 - src.train - INFO     [train.py:62] fold=10/33
# 2022-04-17 11:12:30 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/basalt/fold
- src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_16.csv
# 2022-04-17 11:17:23 - src.train - INFO     [train.py:28] elapsed training time: 0.015 min
# 2022-04-17 11:17:23 - src.train - INFO     [train.py:62] fold=10/33
# 2022-04-17 11:17:23 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_17.csv
# 2022-04-17 11:17:25 - src.train - INFO     [train.py:28] elapsed training time: 0.021 min
# 2022-04-17 11:17:25 - src.train - INFO     [train.py:62] fold=11/33
# 2022-04-17 11:17:25 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_18.csv
# 2022-04-17 11:17:26 - src.train - INFO     [train.py:28] elapsed training time: 0.019 min
# 2022-04-17 11:17:26 - src.train - INFO     [train.py:62] fold=12/33
# 2022-04-17 11:17:26 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_19.csv
# 2022-04-17 11:17:27 - src.train - INFO     [train.py:28] elapsed training time: 0.018 min
# 2022-04-17 11:17:27 - src.train - INFO     [train.py:62] fold=13/33
# 2022-04-17 11:17:27 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_2.csv
# 2022-04-17 11:17:29 - src.train - INFO     [train.py:28] elapsed training time: 0.023 min
# 2022-04-17 11:17:29 - src.train - INFO     [train.py:62] fold=14/33
# 2022-04-17 11:17:29 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_20.csv
# 2022-04-17 11:17:31 - src.train - INFO     [train.py:28] elapsed training time: 0.040 min
# 2022-04-17 11:17:31 - src.train - INFO     [train.py:62] fold=15/33
# 2022-04-17 11:17:31 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_21.csv
# 2022-04-17 11:17:34 - src.train - INFO     [train.py:28] elapsed training time: 0.047 min
# 2022-04-17 11:17:34 - src.train - INFO     [train.py:62] fold=16/33
# 2022-04-17 11:17:34 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_22.csv
# 2022-04-17 11:17:36 - src.train - INFO     [train.py:28] elapsed training time: 0.032 min
# 2022-04-17 11:17:36 - src.train - INFO     [train.py:62] fold=17/33
# 2022-04-17 11:17:36 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_23.csv
# 2022-04-17 11:17:38 - src.train - INFO     [train.py:28] elapsed training time: 0.022 min
# 2022-04-17 11:17:38 - src.train - INFO     [train.py:62] fold=18/33
# 2022-04-17 11:17:38 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_24.csv
# 2022-04-17 11:17:40 - src.train - INFO     [train.py:28] elapsed training time: 0.032 min
# 2022-04-17 11:17:40 - src.train - INFO     [train.py:62] fold=19/33
# 2022-04-17 11:17:40 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_25.csv
# 2022-04-17 11:17:41 - src.train - INFO     [train.py:28] elapsed training time: 0.013 min
# 2022-04-17 11:17:41 - src.train - INFO     [train.py:62] fold=20/33
# 2022-04-17 11:17:41 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_26.csv
# 2022-04-17 11:17:42 - src.train - INFO     [train.py:28] elapsed training time: 0.013 min
# 2022-04-17 11:17:42 - src.train - INFO     [train.py:62] fold=21/33
# 2022-04-17 11:17:42 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_27.csv
# 2022-04-17 11:17:43 - src.train - INFO     [train.py:28] elapsed training time: 0.016 min
# 2022-04-17 11:17:43 - src.train - INFO     [train.py:62] fold=22/33
# 2022-04-17 11:17:43 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_28.csv
# 2022-04-17 11:17:44 - src.train - INFO     [train.py:28] elapsed training time: 0.024 min
# 2022-04-17 11:17:44 - src.train - INFO     [train.py:62] fold=23/33
# 2022-04-17 11:17:44 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_29.csv
# 2022-04-17 11:17:46 - src.train - INFO     [train.py:28] elapsed training time: 0.024 min
# 2022-04-17 11:17:46 - src.train - INFO     [train.py:62] fold=24/33
# 2022-04-17 11:17:46 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_3.csv
# 2022-04-17 11:17:47 - src.train - INFO     [train.py:28] elapsed training time: 0.020 min
# 2022-04-17 11:17:47 - src.train - INFO     [train.py:62] fold=25/33
# 2022-04-17 11:17:47 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_30.csv
# 2022-04-17 11:17:49 - src.train - INFO     [train.py:28] elapsed training time: 0.026 min
# 2022-04-17 11:17:49 - src.train - INFO     [train.py:62] fold=26/33
# 2022-04-17 11:17:49 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_31.csv
# 2022-04-17 11:17:50 - src.train - INFO     [train.py:28] elapsed training time: 0.016 min
# 2022-04-17 11:17:50 - src.train - INFO     [train.py:62] fold=27/33
# 2022-04-17 11:17:50 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_32.csv
# 2022-04-17 11:17:51 - src.train - INFO     [train.py:28] elapsed training time: 0.017 min
# 2022-04-17 11:17:51 - src.train - INFO     [train.py:62] fold=28/33
# 2022-04-17 11:17:51 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_4.csv
# 2022-04-17 11:17:52 - src.train - INFO     [train.py:28] elapsed training time: 0.014 min
# 2022-04-17 11:17:52 - src.train - INFO     [train.py:62] fold=29/33
# 2022-04-17 11:17:52 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_5.csv
# 2022-04-17 11:17:53 - src.train - INFO     [train.py:28] elapsed training time: 0.016 min
# 2022-04-17 11:17:53 - src.train - INFO     [train.py:62] fold=30/33
# 2022-04-17 11:17:53 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_6.csv
# 2022-04-17 11:17:54 - src.train - INFO     [train.py:28] elapsed training time: 0.016 min
# 2022-04-17 11:17:54 - src.train - INFO     [train.py:62] fold=31/33
# 2022-04-17 11:17:54 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_7.csv
# 2022-04-17 11:17:56 - src.train - INFO     [train.py:28] elapsed training time: 0.020 min
# 2022-04-17 11:17:56 - src.train - INFO     [train.py:62] fold=32/33
# 2022-04-17 11:17:56 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_8.csv
# 2022-04-17 11:17:57 - src.train - INFO     [train.py:28] elapsed training time: 0.015 min
# 2022-04-17 11:17:57 - src.train - INFO     [train.py:62] fold=33/33
# 2022-04-17 11:17:57 - src.train - INFO     [train.py:63] reading cv index from data/cv_index/cv-model-test/sulfide/fold_9.csv
# 2022-04-17 11:17:58 - src.train - INFO     [train.py:28] elapsed training time: 0.014 min

# %%
def predict_multiclass_fn(model, test_data):
    probs = model.predict_proba(test_data)
    return probs[:, 2:].sum(axis=1)

# %%
scores = {}

for target_name in cfg.TARGETS:
    cv_paths = get_cv_paths(cv_dir, target_name)
    model = models[target_name]
    scores[target_name] = inference.cross_validation_inference(data, target_name, model, cv_paths, predict_multiclass_fn)
scores = pd.DataFrame(scores)

# %%
cv_scores = scores.mean()

# %%
cv_scores
# Out:
# basalt            0.112896
# carbonate         0.075074
# chloride          0.142640
# iron_oxide        0.171367
# oxalate           0.019858
# oxychlorine       0.122891
# phyllosilicate    0.203330
# silicate          0.165229
# sulfate           0.164459
# sulfide           0.052669
# dtype: float64

# %% [markdown]
# uniform distribution
# basalt            0.148178
# carbonate         0.105477
# chloride          0.165927
# iron_oxide        0.194785
# oxalate           0.028967
# oxychlorine       0.155488
# phyllosilicate    0.253738
# silicate          0.182060
# sulfate           0.189164
# sulfide           0.063096
# dtype: float64

# %%
avg_loss = cv_scores.mean()

# %%
avg_loss
# Out:
# 0.12304118681822954

# %%
test_dir = Path(dirs['test'])

# %%
pd_test_agg_features = pd.read_csv(test_dir / 'mz_agg_features.csv', index_col='sample_id')


pd_test_cluster_features = pd.read_csv(test_dir / 'ae_clusters.csv', index_col='sample_id')

test_sample_features = pd.read_csv(test_dir / 'sample_features.csv', index_col='sample_id')
pd_test_features = pd.concat((test_sample_features, pd_test_agg_features, pd_test_cluster_features), axis=1)

# %%
pd_test_features.head()
# Out:
#            sample_mol_ion_less99  sample_weighted_mass  sample_max_temp  \
# sample_id
# S0766                          0              0.005432         0.501948
# S0767                          0              0.065747         0.930877
# S0768                          0              0.342944         0.849340
# S0769                          0              0.864026         0.081626
# S0770                          0              0.765547         0.674757
#
#            sample_min_temp  sample_temp_range   sum_mz0   sum_mz1   sum_mz2  \
# sample_id
# S0766             0.340250           0.505124  0.926832  0.920168  0.871866
# S0767             0.220117           0.934335  0.875786  0.857193  0.809102
# S0768             0.737245           0.847321  0.614612  0.576422  0.549181
# S0769             0.962396           0.081617  0.145793  0.101693  0.068192
# S0770             0.653061           0.675945  0.482291  0.446705  0.411472
#
#             sum_mz3   sum_mz5  ...  cluster_mz90  cluster_mz91  cluster_mz92  \
# sample_id                      ...
# S0766      0.897009  0.924933  ...           6.0           6.0           7.0
# S0767      0.840202  0.874561  ...           7.0           7.0           8.0
# S0768      0.580665  0.569098  ...           7.0           8.0           7.0
# S0769      0.111700  0.105252  ...          11.0          10.0           7.0
# S0770      0.443042  0.465338  ...           8.0           0.0           9.0
#
#            cluster_mz93  cluster_mz94  cluster_mz95  cluster_mz96  \
# sample_id
# S0766               7.0           6.0           8.0           7.0
# S0767               7.0           8.0           8.0           7.0
# S0768               0.0           7.0           7.0           8.0
# S0769              11.0           4.0           7.0           8.0
# S0770               7.0           7.0           8.0           6.0
#
#            cluster_mz97  cluster_mz98  cluster_mz99
# sample_id
# S0766               7.0           6.0           8.0
# S0767               7.0           7.0           7.0
# S0768               6.0           7.0           6.0
# S0769              10.0           7.0           6.0
# S0770               6.0           7.0           8.0
#
# [5 rows x 698 columns]

# %%
from src.preprocessing import post_processing_prediction

# %%
test_yhat = {}

for target_name in cfg.TARGETS:
    target_models = models[target_name]
    target_yhat = np.mean([predict_multiclass_fn(model, pd_test_features) for model in target_models], axis=0)
    target_yhat = post_processing_prediction(pd_test_features, target_name, target_yhat)
    test_yhat[target_name] = target_yhat
test_yhat = pd.DataFrame(test_yhat, index=pd_test_features.index)

# %%
train_yhat = {}
for target_name in cfg.TARGETS:
    target_models = models[target_name]
    cv_paths = get_cv_paths(cv_dir, target_name)
    target_yhat = inference.compute_avg_prediction(data, target_models, cv_paths, predict_multiclass_fn)
    train_yhat[target_name] = target_yhat
train_yhat = pd.DataFrame(train_yhat)

# %%
sub_dir = Path(dirs['submission'])

# %%
sub_dir = sub_dir.joinpath('lgbm', 'test')

# %%
sub_dir.mkdir(exist_ok=True, parents=True)

# %%
test_yhat.to_csv(sub_dir / 'submission.csv', index=True)

# %%
train_yhat.to_csv(sub_dir / 'train.csv', index=True)
